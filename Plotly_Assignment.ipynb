# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import ast 
from collections import Counter
from wordcloud import WordCloud
import json

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
print("Shape of movies dataset:",movies.shape)
print("Shape of credits dataset:",credits.shape)
# Out:
# Shape of movies dataset: (4803, 20)
# Shape of credits dataset: (4803, 4)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %% [markdown]
# ## Q1: Combine the two datsets as one dataframe

# %%
movies_credit = pd.concat([movies,credits],axis=1) 
movies_credit
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ## Q2: Remove the following columns:
# - 'homepage','tagline','id','overview','status','original_title','movie_id'.

# %%
movies_credit = movies_credit.drop(columns=['homepage','tagline','id','overview','status','original_title','movie_id'])

# %%
movies.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %% [markdown]
# ## Q3: Create Genres dataframe that hase two coulumns Genres and Frequency
# - Hint: Use Counter to calculate Frequency
# - Add new catagory to Genres called Others if the Frequency < 200 consider

# %%
genres = Counter()
for movie in movies.genres:
    movie = json.loads(movie)
    for category in movie:
          genres[category ["name"]] += 1
Genres = pd.DataFrame.from_dict(genres, orient='index').reset_index()
Genres = Genres.rename(columns = {'index': 'Genres',0: 'Frequency'})
Genres.loc [Genres ['Frequency'] < 200, 'Genres'] = 'Others'
Genres
# Out:
#              Genres  Frequency
# 0            Action       1154
# 1         Adventure        790
# 2           Fantasy        424
# 3   Science Fiction        535
# 4             Crime        696
# 5             Drama       2297
# 6          Thriller       1274
# 7         Animation        234
# 8            Family        513
# 9            Others         82
# 10           Comedy       1722
# 11          Romance        894
# 12           Horror        519
# 13          Mystery        348
# 14           Others        197
# 15           Others        144
# 16           Others        185
# 17           Others        110
# 18           Others         34
# 19           Others          8

# %% [markdown]
# ## Q4: Use bar chart draws the relationship between genres of movies and Frequency.

# %%
px.bar(Genres , x ='Genres' , y='Frequency')
# Out:
# <div>                            <div id="f8b37549-111b-4375-8b28-a09af9ae6997" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8b37549-111b-4375-8b28-a09af9ae6997")) {                    Plotly.newPlot(                        "f8b37549-111b-4375-8b28-a09af9ae6997",                        [{"alignmentgroup":"True","hovertemplate":"Genres=%{x}<br>Frequency=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Action","Adventure","Fantasy","Science Fiction","Crime","Drama","Thriller","Animation","Family","Others","Comedy","Romance","Horror","Mystery","Others","Others","Others","Others","Others","Others"],"xaxis":"x","y":[115
# ...

# %% [markdown]
# ## Q5: Use pie chart to draw top 5 languages.
# - Hint: use counter to create dataframe contains production_countries with Frequencies.

# %%
country_split = [item for row in movies_credit['production_countries'] for item in row] 



data = Counter(country_split)
country_f = pd.DataFrame.from_dict(data=data, orient='index').reset_index() 
country_f = country_f.rename(columns={'index':'production country', 0:'frequency'}) 
country_f = country_f.sort_values('frequency', ascending=False) 

top_five = country_f.head() 
top_five
# Out:
#    production country  frequency
# 2                   "      51488
# 11                         33793
# 18                  e      19992
# 16                  a      16820
# 3                   i      16187

# %% [markdown]
# ## Q6: Use WordCloud to draw genres.

# %%
wordcloud = WordCloud(background_color ='white').generate(" ".join(list(Genres['Genres'])))    

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Q7: Use scatter plot to draw the relationship between budget and revenue.

# %%
px.scatter(df, x="budget", y="revenue")
# Out:
# <div>                            <div id="23fd5da8-8bc1-4d5c-8047-736cf2e6ba10" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23fd5da8-8bc1-4d5c-8047-736cf2e6ba10")) {                    Plotly.newPlot(                        "23fd5da8-8bc1-4d5c-8047-736cf2e6ba10",                        [{"hovertemplate":"budget=%{x}<br>revenue=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[237000000,300000000,245000000,250000000,260000000,258000000,260000000,280000000,250000000,250000000,270000000,200000000,200000000,255000000,225000000,225000000,220000000,380000000,225000000,250000000,215000000,200000000,250000000,180000000,207000000,200000000,250000000,209000000,150000000,
# ...

# %% [markdown]
# ## Q8: Use line chart to draw the relationship between revenue and popularity.

# %%
px.line(df, x='revenue', y='popularity')
# Out:
# <div>                            <div id="9a0661ed-82a1-4fe7-8ccd-43e9ad9401a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a0661ed-82a1-4fe7-8ccd-43e9ad9401a4")) {                    Plotly.newPlot(                        "9a0661ed-82a1-4fe7-8ccd-43e9ad9401a4",                        [{"hovertemplate":"revenue=%{x}<br>popularity=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[2787965087,961000000,880674609,1084939099,284139100,890871626,591794936,1405403694,933959197,873260194,391081192,586090727,1065659812,89289910,662845518,419651413,1519557910,1045713802,624026776,956019788,752215857,310669540,958400000,372234864,550000000,184503418
# ...
